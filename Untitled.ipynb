# %%
import pandas as pd
import numpy as np

# %%
ds = pd.read_csv("CIN.csv")

# %%
ds.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
X = ds.iloc[:, :-2]
Y = ds.iloc[:, -2]

# %%
X = X.values
Y = Y.values

# %%
X.shape
# Out:
# (5000, 5)

# %%
for i in X:
    print(str(i[0]) + "," + str(i[1]) + "," + str(i[2]) + "," + str(i[3]) + "," + str(i[4]))
# Out:
# 79545.45857431678,5.682861321615587,7.009188142792237,4.09,23086.800502686456
# 79248.64245482568,6.0028998082752425,6.730821019094919,3.09,40173.07217364482
# 61287.067178656784,5.865889840310001,8.512727430375099,5.13,36882.15939970458
# 63345.24004622798,7.1882360945186425,5.586728664827653,3.26,34310.24283090706
# 59982.19722570803,5.040554523106283,7.839387785120487,4.23,26354.109472103148
# 80175.7541594853,4.9884077575337145,6.104512439428879,4.04,26748.428424689715
# 64698.46342788773,6.025335906887152,8.147759585023431,3.41,60828.24908540716
# 78394.33927753085,6.9897797477182815,6.620477995185026,2.42,36516.358972493836
# 59927.66081334963,5.36212556960358,6.3931209805509015,2.3,29387.39600281585
# 81885.92718409566,4.423671789897876,8.167688003472351,6.1,40149.96574921337
# 80527.47208292288,8.09351268063935,5.042746799645982,4.1,47224.359840221914
# 50593.69549704281,4.496512793097035,7.467627404008019,4.49,34343.991885578806
# ...

# %%
for i in Y:
    print(i)
# Out:
# 1059033.5578701235
# 1505890.91484695
# 1058987.9878760849
# 1260616.8066294468
# 630943.4893385402
# 1068138.0743935304
# 1502055.8173744078
# 1573936.5644777215
# 798869.5328331633
# 1545154.8126419624
# 1707045.722158058
# 663732.3968963273
# 1042814.0978200928
# 1291331.5184858206
# 1402818.2101658515
# 1306674.6599511993
# 1556786.6001947748
# 528485.2467305964
# 1019425.9367578316
# 1030591.4292116085
# 2146925.339888662
# 929247.5995364
# 718887.2315009277
# 743999.8191601974
# 895737.1333835076
# 1453974.5059508719
# 1125692.507295288
# 975429.4927929222
# 1240763.765571478
# 1577017.7600015546
# 1246830.1884286287
# 1170720.893654292
# 1071279.210244544
# 534305.1323349292
# 936368.9634048606
# 1199193.8313295112
# 1233220.009477811
# 1081150.1254838074
# 524712.7660674525
# 302355.83597895555
# 1026817.399788458
# 1762214.6795818857
# 882057.1705928424
# 1744932.210990927
# 1153871.4695016337
# 1499988.8795226102
# 1109588.380162506
# 980177.3051371257
# 1323952.027425176
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
MMSX = MinMaxScaler()

# %%
X_T = MMSX.fit_transform(X)

# %%
for i in X_T:
    print(str(i[0]) + "," + str(i[1]) + "," + str(i[2]) + "," + str(i[3]) + "," + str(i[4]))
# Out:
# 0.6868221667025349,0.4419858410930908,0.5015015779634246,0.46444444444444444,0.3299422012433329
# 0.683520729267443,0.4885383571054248,0.46450137404823766,0.24222222222222223,0.5759680101994691
# 0.4837370480050029,0.46860900800081506,0.7013501071149905,0.6955555555555555,0.5285820448464251
# 0.5066297701541234,0.6609563278978813,0.3124300739484295,0.2799999999999999,0.49154893039105785
# 0.4692231916889185,0.34855646066287527,0.6118506581581867,0.49555555555555564,0.37698829460942845
# 0.6938328420109252,0.3409712381334049,0.3812532344918136,0.45333333333333337,0.38266610666609496
# 0.5216814537955403,0.4918018922220495,0.6528390454596579,0.31333333333333335,0.8733826075270911
# 0.674018453935245,0.6320890427204021,0.44983471969963096,0.09333333333333327,0.5233148720100016
# 0.46861659204182277,0.39533190147755515,0.4196147145809308,0.06666666666666665,0.42066469089328123
# 0.7128548184912229,0.2588252423486346,0.6554879054849495,0.911111111111111,0.5756353000054427
# ...

# %%
np.max(X[:, 1])
# Out:
# 9.51908806613594

# %%
w = [0.840188, 0.394383, 0.783099, 0.79844, 0.911647]

# %%
x = np.array("0.738572 0.596996 0.651436 0.629231 0.331603".split(" ")).astype(float)

# %%
w
# Out:
# [0.840188, 0.394383, 0.783099, 0.79844, 0.911647]

# %%
x = np.array(x)

# %%
w * x
# Out:
# array([0.62053933, 0.23544507, 0.51013888, 0.5024032 , 0.30230488])

# %%
y_ = sum(w * x) + 0.197551

# %%
Y = 0.428921

# %%
dW = (y_ - Y) * x

# %%
dW
# Out:
# array([1.43243186, 1.15785068, 1.26343495, 1.22036921, 0.64313121])

# %%
y_
# Out:
# 2.3683823649489995

# %%
db = y_ - Y

# %%
b = 0.197551 - 0.05 * db

# %%
w = w - 0.05 * dW

# %%
w
# Out:
# array([0.76856641, 0.33649047, 0.71992725, 0.73742154, 0.87949044])

# %%
sum(w * x) + b
# Out:
# 2.0937397128488464
